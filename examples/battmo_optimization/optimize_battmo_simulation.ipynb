# %% [markdown]
# # Overview
# In this example we will optimize the energy density of a battery cell by fine-tuning the thickness of three components
# 1. The positive electrode (30 - 150 microns)
# 2. The negative electrode (30 - 150 microns)
# 3. The separator (8-15 microns)
#
# - The simulations will be done on the [Battmo Server](https://github.com/OpenBattTools/BattMo-Server).
# - The parameter suggestions will be done using this wrapper to call SDLabs.

# %%
import sdlabs_wrapper.wrapper as at
import sdlabs_wrapper.models as at_models
import getpass
from typing import Dict
import requests
import random

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Battmo functions

# %%
# constants
BATTMO_URL= "https://api.battmo.open-semantic-lab.org/api/run/performance-spec"

# %% [markdown]
# Test battmo server by sending a sample request

# %%
def send_battmo_request(batt_suggestion:Dict[str,any],battmo_url=BATTMO_URL):
    print(f"Sending request to Battmo with {batt_suggestion}")
    resp = requests.post(battmo_url, json = batt_suggestion).json()
    print(f"Received response {resp}")
    return resp["result"]

# %%
send_battmo_request({    "geometry": {
                "format": "1D",
                    "faceArea": 0.0001,
                    "NegativeElectrode": {
                      "ActiveMaterial": {
                        "thickness": 15e-6
                      }
                    },
                    "PositiveElectrode": {
                      "ActiveMaterial": {
                        "thickness": 50e-6
                      }
                    },
                    "Electrolyte": {
                      "Separator": {
                        "thickness": 50e-6
                      }
                    }
    }
            })
# Out:
# Sending request to Battmo with {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 1.5e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 5e-05}}, 'Electrolyte': {'Separator': {'thickness': 5e-05}}}}
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): api.battmo.open-semantic-lab.org:443
# DEBUG:urllib3.connectionpool:https://api.battmo.open-semantic-lab.org:443 "POST /api/run/performance-spec HTTP/1.1" 200 97
# Received response {'status': 'ok', 'result': {'E': 3.0, 'energyDensity': 1031368648.2790359, 'energy': 11.860739455208918}}
# {'E': 3.0, 'energyDensity': 1031368648.2790359, 'energy': 11.860739455208918}

# %% [markdown]
# ## Atinary Wrapper
# Atinary wrapper can be instantiated from a config file (see `./optimization_config.json`).
# We also need an api_key which you can access under your account at [home.atinary.com](home.atinary.com)
# The wrapper uses the models available at `atinary/src/sdlabs_wrapper/models.py`. A JSON schema is available under `sdlabs_wrapper_schema.json`

# %%
api_key = getpass.getpass()

# %%
def transform_atinary_to_battmo(at_recommendation:at_models.Recommendation):
     return {    "geometry": {
                "format": "1D",
                    "faceArea": 0.0001,
                    "NegativeElectrode": {
                      "ActiveMaterial": {
                        "thickness": at_recommendation.param_values['neg_electrode_thickness']
                      }
                    },
                    "PositiveElectrode": {
                      "ActiveMaterial": {
                        "thickness": at_recommendation.param_values['pos_electrode_thickness']
                      }
                    },
                    "Electrolyte": {
                      "Separator": {
                        "thickness": at_recommendation.param_values['separator_thickness']
                      }
                    }
    }
            }

# %%
# look at config.json
# !cat ./optimization_config.json
# Out:
# {
#     "optimization_name": "BattmoSimulation New wrapper",
#     "description": "Optimize cell layer thicknesses",
#     "sdlabs_group_id": "onterface",
#     "parameters": [
#         {
#             "low_value": 30e-6,
#             "high_value": 150e-6,
#             "name": "neg_electrode_thickness"
#         },
#         {
#             "low_value": 30e-6,
#             "high_value": 150e-6,
#             "name": "pos_electrode_thickness"
#         },
#         {
#             "low_value": 8e-6,
#             "high_value": 15e-6,
#             "name": "separator_thickness"
#         }
#     ],
#     "multi_objective_function": "chimera",
#     "objectives": [
#         {
#             "name": "energy_density",
#             "goal": "maximize"
#         }
#     ],
#     "inherit_data": false,
#     "always_restart": false,
#     "batch_size": 1,
#     "algorithm": "dragonfly",
#     "budget": 20
# }

# %%
sdlabs_wrapper = at.initialize_optimization(
    inherit_data=False,
    always_restart=True,
    spec_file_path="./optimization_config.json",
    api_key=api_key,
)
print(f"Optimization loaded and started according to configuration file.")
for iteration in range(sdlabs_wrapper.config.budget):
    print("Waiting for new suggestions")
    suggestions = sdlabs_wrapper.get_new_suggestions(max_retries=10, sleep_time_s=15)
    print(f"Iteration {iteration+1} New Atinary suggestions: {suggestions}")
    for suggestion in suggestions:
        # transform to battmo format:
        print(suggestion.param_values)
        battmo_param = transform_atinary_to_battmo(suggestion)
        print(f"Battmo parameters: {battmo_param}")
        # Call Battmo here
        response = send_battmo_request(battmo_param)
        print(f"Battmo response {response}") 
        
        # measurements should be in the form of a dict with keys matching objectives and numerical values
        suggestion.measurements = {sdlabs_wrapper.config.objectives[0].name:response["energyDensity"]}
    if suggestions:
        print(f"Sending measurements back to SDLabs")
        sdlabs_wrapper.send_measurements(suggestions)
# Out:
# INFO:sdlabs_wrapper.wrapper:Creating new workstation associated to parameters [Parameter(name='neg_electrode_thickness', type='continuous', high_value=0.00015, low_value=3e-05, stride=None, description=None, descriptors=None), Parameter(name='pos_electrode_thickness', type='continuous', high_value=0.00015, low_value=3e-05, stride=None, description=None, descriptors=None), Parameter(name='separator_thickness', type='continuous', high_value=1.5e-05, low_value=8e-06, stride=None, description=None, descriptors=None)] and measurements ['energy_density']
# INFO:sdlabs_wrapper.wrapper:Linked to workstation 'wst_bb7c0e99709c4a9e8dd5f13ab08d1c62'
# INFO:sdlabs_wrapper.wrapper:New campaign launched! Preload data set to 'False'.
# INFO:sdlabs_wrapper.wrapper:Running optimization associated with campaign id : 'cpg_758f9e51b6cb47fe99943b4930d0fa3b' associated to template 'tpl_77979453da0c49f1a64ecb089be7d597'
# Optimization loaded and started according to configuration file.
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# Iteration 1 New Atinary suggestions: [Recommendation(iteration=0, batch=0, param_values={'neg_electrode_thickness': 3.26e-05, 'pos_electrode_thickness': 9.66e-05, 'separator_thickness': 1.451e-05}, _param_file_id='fle_441fbe38e7b549c3b22bbee11a299b07', measurements=None)]
# {'neg_electrode_thickness': 3.26e-05, 'pos_electrode_thickness': 9.66e-05, 'separator_thickness': 1.451e-05}
# Battmo parameters: {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 3.26e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 9.66e-05}}, 'Electrolyte': {'Separator': {'thickness': 1.451e-05}}}}
# Sending request to Battmo with {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 3.26e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 9.66e-05}}, 'Electrolyte': {'Separator': {'thickness': 1.451e-05}}}}
# Received response {'status': 'ok', 'result': {'E': 3.0, 'energyDensity': 1785581368.712117, 'energy': 25.660589849761834}}
# Battmo response {'E': 3.0, 'energyDensity': 1785581368.712117, 'energy': 25.660589849761834}
# Sending measurements back to SDLabs
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# INFO:sdlabs_wrapper.wrapper:Properties uploaded fle_441fbe38e7b549c3b22bbee11a299b07:job_submission_a72a802abc474d09bcb42b022af81fa8.yml
# INFO:sdlabs_wrapper.wrapper:Parameter file deleted fle_441fbe38e7b549c3b22bbee11a299b07:job_submission_a72a802abc474d09bcb42b022af81fa8.yml
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 2 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# Iteration 3 New Atinary suggestions: [Recommendation(iteration=1, batch=0, param_values={'neg_electrode_thickness': 0.0001378, 'pos_electrode_thickness': 5.68e-05, 'separator_thickness': 1.164e-05}, _param_file_id='fle_274daa192ea54621b9643bbd14dc9426', measurements=None)]
# {'neg_electrode_thickness': 0.0001378, 'pos_electrode_thickness': 5.68e-05, 'separator_thickness': 1.164e-05}
# Battmo parameters: {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 0.0001378}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 5.68e-05}}, 'Electrolyte': {'Separator': {'thickness': 1.164e-05}}}}
# Sending request to Battmo with {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 0.0001378}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 5.68e-05}}, 'Electrolyte': {'Separator': {'thickness': 1.164e-05}}}}
# Received response {'status': 'ok', 'result': {'E': 3.0, 'energyDensity': 2158349306.7487183, 'energy': 44.51379610238556}}
# Battmo response {'E': 3.0, 'energyDensity': 2158349306.7487183, 'energy': 44.51379610238556}
# Sending measurements back to SDLabs
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# INFO:sdlabs_wrapper.wrapper:Properties uploaded fle_274daa192ea54621b9643bbd14dc9426:job_submission_f56ff75f9d444b6e85d4b9f60e741515.yml
# INFO:sdlabs_wrapper.wrapper:Parameter file deleted fle_274daa192ea54621b9643bbd14dc9426:job_submission_f56ff75f9d444b6e85d4b9f60e741515.yml
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# Iteration 4 New Atinary suggestions: [Recommendation(iteration=2, batch=0, param_values={'neg_electrode_thickness': 8.62e-05, 'pos_electrode_thickness': 5.19e-05, 'separator_thickness': 9.91e-06}, _param_file_id='fle_73ee7c4687684a899faea585d1c4aef5', measurements=None)]
# {'neg_electrode_thickness': 8.62e-05, 'pos_electrode_thickness': 5.19e-05, 'separator_thickness': 9.91e-06}
# Battmo parameters: {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 8.62e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 5.19e-05}}, 'Electrolyte': {'Separator': {'thickness': 9.91e-06}}}}
# Sending request to Battmo with {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 8.62e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 5.19e-05}}, 'Electrolyte': {'Separator': {'thickness': 9.91e-06}}}}
# Received response {'status': 'ok', 'result': {'E': 3.0, 'energyDensity': 2747424121.5458293, 'energy': 40.66462442299982}}
# Battmo response {'E': 3.0, 'energyDensity': 2747424121.5458293, 'energy': 40.66462442299982}
# Sending measurements back to SDLabs
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# INFO:sdlabs_wrapper.wrapper:Properties uploaded fle_73ee7c4687684a899faea585d1c4aef5:job_submission_f06aa3c31e9d44fca0c3420e4b36c83b.yml
# INFO:sdlabs_wrapper.wrapper:Parameter file deleted fle_73ee7c4687684a899faea585d1c4aef5:job_submission_f06aa3c31e9d44fca0c3420e4b36c83b.yml
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 5 New Atinary suggestions: [Recommendation(iteration=3, batch=0, param_values={'neg_electrode_thickness': 0.000103, 'pos_electrode_thickness': 0.0001068, 'separator_thickness': 9.31e-06}, _param_file_id='fle_4b74720ca535482d992dd8137668dacc', measurements=None)]
# {'neg_electrode_thickness': 0.000103, 'pos_electrode_thickness': 0.0001068, 'separator_thickness': 9.31e-06}
# Battmo parameters: {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 0.000103}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 0.0001068}}, 'Electrolyte': {'Separator': {'thickness': 9.31e-06}}}}
# Sending request to Battmo with {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 0.000103}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 0.0001068}}, 'Electrolyte': {'Separator': {'thickness': 9.31e-06}}}}
# Received response {'status': 'ok', 'result': {'E': 3.0, 'energyDensity': 3514537030.291241, 'energy': 77.0070208707114}}
# Battmo response {'E': 3.0, 'energyDensity': 3514537030.291241, 'energy': 77.0070208707114}
# Sending measurements back to SDLabs
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# INFO:sdlabs_wrapper.wrapper:Properties uploaded fle_4b74720ca535482d992dd8137668dacc:job_submission_ce80d0071ec546ee883224e71d7a9d30.yml
# INFO:sdlabs_wrapper.wrapper:Parameter file deleted fle_4b74720ca535482d992dd8137668dacc:job_submission_ce80d0071ec546ee883224e71d7a9d30.yml
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 6 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# Iteration 7 New Atinary suggestions: [Recommendation(iteration=4, batch=0, param_values={'neg_electrode_thickness': 7.75e-05, 'pos_electrode_thickness': 0.0001312, 'separator_thickness': 1.267e-05}, _param_file_id='fle_778e3cff1c9c4c368487f20734b72429', measurements=None)]
# {'neg_electrode_thickness': 7.75e-05, 'pos_electrode_thickness': 0.0001312, 'separator_thickness': 1.267e-05}
# Battmo parameters: {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 7.75e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 0.0001312}}, 'Electrolyte': {'Separator': {'thickness': 1.267e-05}}}}
# Sending request to Battmo with {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 7.75e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 0.0001312}}, 'Electrolyte': {'Separator': {'thickness': 1.267e-05}}}}
# Received response {'status': 'ok', 'result': {'E': 3.0, 'energyDensity': 2689095112.044903, 'energy': 59.52849849533802}}
# Battmo response {'E': 3.0, 'energyDensity': 2689095112.044903, 'energy': 59.52849849533802}
# Sending measurements back to SDLabs
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# INFO:sdlabs_wrapper.wrapper:Properties uploaded fle_778e3cff1c9c4c368487f20734b72429:job_submission_30ddc12e928943969ee3187d9980c47c.yml
# INFO:sdlabs_wrapper.wrapper:Parameter file deleted fle_778e3cff1c9c4c368487f20734b72429:job_submission_30ddc12e928943969ee3187d9980c47c.yml
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# Iteration 8 New Atinary suggestions: [Recommendation(iteration=5, batch=0, param_values={'neg_electrode_thickness': 8.37e-05, 'pos_electrode_thickness': 9.66e-05, 'separator_thickness': 1.112e-05}, _param_file_id='fle_fbca16ca43af47658e0082361586a99c', measurements=None)]
# {'neg_electrode_thickness': 8.37e-05, 'pos_electrode_thickness': 9.66e-05, 'separator_thickness': 1.112e-05}
# Battmo parameters: {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 8.37e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 9.66e-05}}, 'Electrolyte': {'Separator': {'thickness': 1.112e-05}}}}
# Sending request to Battmo with {'geometry': {'format': '1D', 'faceArea': 0.0001, 'NegativeElectrode': {'ActiveMaterial': {'thickness': 8.37e-05}}, 'PositiveElectrode': {'ActiveMaterial': {'thickness': 9.66e-05}}, 'Electrolyte': {'Separator': {'thickness': 1.112e-05}}}}
# Received response {'status': 'ok', 'result': {'E': 3.0, 'energyDensity': 3306041722.44686, 'energy': 63.284250651077784}}
# Battmo response {'E': 3.0, 'energyDensity': 3306041722.44686, 'energy': 63.284250651077784}
# Sending measurements back to SDLabs
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Successfully fetched '1' files
# INFO:sdlabs_wrapper.wrapper:Properties uploaded fle_fbca16ca43af47658e0082361586a99c:job_submission_a74b5fd10c17454bae22ab848606e70a.yml
# INFO:sdlabs_wrapper.wrapper:Parameter file deleted fle_fbca16ca43af47658e0082361586a99c:job_submission_a74b5fd10c17454bae22ab848606e70a.yml
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 9 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 10 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 11 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 12 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 13 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 14 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 15 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 16 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 17 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 18 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 19 New Atinary suggestions: []
# Waiting for new suggestions
# INFO:sdlabs_wrapper.wrapper:Retry 0. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 1. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 2. Fetching parameter files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Waiting 15 s for new files...
# INFO:sdlabs_wrapper.wrapper:Retry 3. Fetching parameter files...
# Iteration 20 New Atinary suggestions: []

# %% [markdown]
# You can now access the platform to create a custom report of your optimization under https://home.atinary.com Here is a sample demo of the optimization under the Analytics dashboard of SDLabs.
# ![Optimization plot](analytics_demo.png)
